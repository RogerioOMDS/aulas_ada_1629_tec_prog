# %% [markdown]
# # Bem Vindo a Técnicas de Programação I
#
# - Quem sou eu?
# - Quem são vocês?
# - O que vocês já sabem?
# - O que veremos neste módulo?

# %% [markdown]
# Rogério Mainardes
#
# - https://www.linkedin.com/in/rogerioomds/
# - Email: r.otavioms@gmail.com
# - GitHub: https://github.com/RogerioOMDS

# %% [markdown]
# # Aula:
#
# - 19h: 10 - 15 min para possíveis dúvidas;
# - 20min de intervalo perto das 20h30;
# - Falo rápido, favor me avise caso se perca;
# - Camera / audio;

# %% [markdown]
# ## Planejamento do módulo
#
# - Semana 1:
#   - Entendendo Git
#   - Vetores em python: Numpy
#   - Matrizes em python? Numpy
#
# - Semana 2:
#   - Indexando vetores: Series
#   - Conhecendo os não extintos: Pandas
#
# - Semana 3:
#   - Processamento de dados com DataFrames
#   - Porque Pandas não é esporte olímpico?
#
# - Semana 4:
#   - Cientista de dados II: Pandas
#   - Projeto

# %%
Anaconda

# %%
print("show")
